# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv('../data/spotify_data.csv')
dataset.head()
# Out:
#                             track_name    artist(s)_name  artist_count  \
# 0  Seven (feat. Latto) (Explicit Ver.)  Latto, Jung Kook             2
# 1                                 LALA       Myke Towers             1
# 2                              vampire    Olivia Rodrigo             1
# 3                         Cruel Summer      Taylor Swift             1
# 4                       WHERE SHE GOES         Bad Bunny             1
#
#    released_year  released_month  released_day  in_spotify_playlists  \
# 0           2023               7            14                   553
# 1           2023               3            23                  1474
# 2           2023               6            30                  1397
# 3           2019               8            23                  7858
# 4           2023               5            18                  3133
#
#    in_spotify_charts    streams  in_apple_playlists  ...  bpm key   mode  \
# ...

# %%
first_200 = dataset.iloc[:200]

less_than_1970 = first_200.loc[first_200['released_year'] < 1970]
less_than_1970
# Out:
#                        track_name                artist(s)_name  artist_count  \
# 195  Have You Ever Seen The Rain?  Creedence Clearwater Revival             1
#
#      released_year  released_month  released_day  in_spotify_playlists  \
# 195           1968               7             1                 15890
#
#      in_spotify_charts     streams  in_apple_playlists  ...  bpm  key   mode  \
# 195                 14  1145727611                  71  ...  116  NaN  Major
#
#     danceability_%  valence_% energy_% acousticness_%  instrumentalness_%  \
# 195             74         76       70              7                   0
#
#      liveness_%  speechiness_%
# 195          13              3
#
# [1 rows x 24 columns]

# %%
greater_than_1982_and_less_than_1985 = first_200.loc[(first_200['released_year'] < 1985) & (first_200['released_year'] > 1982)]
greater_than_1982_and_less_than_1985
# Out:
#                                   track_name artist(s)_name  artist_count  \
# 166  Every Breath You Take - Remastered 2003     The Police             1
# 199                               Take On Me           a-ha             1
#
#      released_year  released_month  released_day  in_spotify_playlists  \
# 166           1983               1             6                 22439
# 199           1984              10            19                 44927
#
#      in_spotify_charts     streams  in_apple_playlists  ...  bpm key   mode  \
# 166                 19  1593270737                 211  ...  117  C#  Major
# 199                 17  1479115056                  34  ...   84  F#  Minor
#
#     danceability_%  valence_% energy_% acousticness_%  instrumentalness_%  \
# 166             82         73       45             54                   0
# 199             57         86       90              2                   0
#
#      liveness_%  speechiness_%
# 166           7              3
# ...

# %%
greater_than_2012_and_less_than_2015 = first_200.loc[(first_200['released_year'] < 2015) & (first_200['released_year'] > 2012)]
greater_than_2012_and_less_than_2015
# Out:
#                                    track_name  artist(s)_name  artist_count  \
# 22                           I Wanna Be Yours  Arctic Monkeys             1
# 37                                Blank Space    Taylor Swift             1
# 38                                      Style    Taylor Swift             1
# 115                            No Role Modelz         J. Cole             1
# 157                            Counting Stars     OneRepublic             1
# 172                          Do I Wanna Know?  Arctic Monkeys             1
# 176                              Shake It Off    Taylor Swift             1
# 177  Why'd You Only Call Me When You're High?  Arctic Monkeys             1
# 180                             Night Changes   One Direction             1
# 189                         Take Me To Church          Hozier             1
#
#      released_year  released_month  released_day  in_spotify_playlists  \
# ...

# %%
greater_than_2019_and_less_than_or_equal_2022 = first_200.loc[(first_200['released_year'] <= 2022) & (first_200['released_year'] > 2019)]
greater_than_2019_and_less_than_or_equal_2022.head()
# Out:
#                        track_name                       artist(s)_name  \
# 14                      As It Was                         Harry Styles
# 15                      Kill Bill                                  SZA
# 26  Calm Down (with Selena Gomez)                      R��ma, Selena G
# 32                       Creepin'  The Weeknd, 21 Savage, Metro Boomin
# 33                      Anti-Hero                         Taylor Swift
#
#     artist_count  released_year  released_month  released_day  \
# 14             1           2022               3            31
# 15             1           2022              12             8
# 26             2           2022               3            25
# 32             3           2022              12             2
# 33             1           2022              10            21
#
#     in_spotify_playlists  in_spotify_charts     streams  in_apple_playlists  \
# 14                 23575                130  2513188493                 403
# ...

# %%
bins = first_200['released_year'].value_counts()
bins = 25

# %%
plt.hist(first_200['released_year'], bins=bins)
# Out:
# (array([  1.,   0.,   0.,   1.,   0.,   0.,   1.,   2.,   0.,   0.,   1.,
#           0.,   0.,   0.,   1.,   1.,   3.,   1.,   1.,  10.,  18.,   8.,
#          12.,  14., 125.]),
#  array([1968. , 1970.2, 1972.4, 1974.6, 1976.8, 1979. , 1981.2, 1983.4,
#         1985.6, 1987.8, 1990. , 1992.2, 1994.4, 1996.6, 1998.8, 2001. ,
#         2003.2, 2005.4, 2007.6, 2009.8, 2012. , 2014.2, 2016.4, 2018.6,
#         2020.8, 2023. ]),
#  <BarContainer object of 25 artists>)
